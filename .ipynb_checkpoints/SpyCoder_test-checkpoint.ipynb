# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
idx = 3

# %%
data_base = '../../data/raw/dataIBM'
data_exts = '.csv'
targ_df = pd.read_csv(data_base+data_exts, header=None).astype('float64')
mate_df = pd.read_csv(data_base+data_tags+data_exts, header=None)
matd_df = pd.read_csv(data_base+data_tags+'_decode'+data_exts, header=None)

# %%
if idx==0:
    from SpyCoder.Batch import TBR as SPCb
    from SpyCoder.Sequential import TBR as SPCs
    spcb = SPCb(3)
    spcs = SPCs(3)
    data_tags = '_TBR_factor3'
elif idx==1:
    from SpyCoder.Batch import SF as SPCb
    from SpyCoder.Sequential import SF as SPCs
    spcb = SPCb(3)
    spcs = SPCs(3)
    data_tags = '_SF_thr3'
elif idx==2:
    from SpyCoder.Batch import MW as SPCb
    from SpyCoder.Sequential import MW as SPCs
    spcb = SPCb(3, 10)
    spcs = SPCs(3, 10)
    data_tags = '_MW_thr3_wind10'
else:
    from SpyCoder.Batch import BSA as SPCb
    from SpyCoder.Sequential import BSA as SPCs
    spcb = SPCb(1, np.ones(10), np.min(targ_df))
    spcs = SPCs(1, np.ones(10), np.min(targ_df))
    data_tags = '_BSA_fir10x1_thr1'

# %%
mate_df.plot();

# %%
spceb_df = pd.DataFrame(spcb.encode(targ_df.values.squeeze()))

# %%
spceb_df.plot();

# %%
spces_df = pd.DataFrame(targ_df[0].apply(spcs.encode))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-de1d1ec683c7> in <module>
# ----> 1 spces_df = pd.DataFrame(targ_df[0].apply(spcs.encode))
#
# ~\Anaconda3\envs\spikes\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# ~\OneDrive\博士\04. 作業\00. プロジェクト\02. Spikes\spikes\src\utils\SpyCoder\Sequential.py in encode(self, signal, shift)
#     166             self.shift = shift
#     167         elif self.shift is None:
# --> 168             raise ValueError('shift is not set')
#     169
#     170         signal = signal - self.shift
#
# ValueError: shift is not set

# %%
spces_df.plot();

# %%
(spces_df-spceb_df).plot();

# %%
(mate_df-spceb_df).plot();

# %%
targ_df.plot();

# %%
spcdb_df = pd.DataFrame(spcb.decode(spceb_df.values.squeeze()))

# %%
spcdb_df.plot();

# %%
spcds_df = pd.DataFrame(spces_df[0].apply(spcs.decode))

# %%
spcds_df.plot();

# %%
matd_df.plot();

# %%
(spcds_df-spcdb_df).plot()

# %%
(matd_df-spcdb_df).plot();
